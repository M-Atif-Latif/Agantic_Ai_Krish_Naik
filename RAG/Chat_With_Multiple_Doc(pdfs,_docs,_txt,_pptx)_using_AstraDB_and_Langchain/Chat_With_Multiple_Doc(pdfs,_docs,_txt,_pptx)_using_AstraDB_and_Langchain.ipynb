# %%
# !pip install langchain
# !pip install unstructured
# !pip install openai
# !pip install Cython
# !pip install tiktoken
# Out:
# Requirement already satisfied: langchain in c:\users\dell\miniconda3\envs\rag\lib\site-packages (0.3.27)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain) (0.3.72)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain) (0.3.9)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain) (0.4.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain) (2.0.42)
# Requirement already satisfied: requests<3,>=2 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain) (2025.7.14)
# Requirement already satisfied: greenlet>=1 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langsmith>=0.1.17->langchain) (3.11.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: anyio in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.1)
# Collecting unstructured
#   Using cached unstructured-0.18.11-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: charset-normalizer in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from unstructured) (3.4.2)
# Collecting filetype (from unstructured)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting python-magic (from unstructured)
#   Using cached python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting lxml (from unstructured)
#   Using cached lxml-6.0.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Collecting nltk (from unstructured)
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: requests in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from unstructured) (2.32.4)
# Collecting beautifulsoup4 (from unstructured)
#   Using cached beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Collecting emoji (from unstructured)
#   Using cached emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting dataclasses-json (from unstructured)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting python-iso639 (from unstructured)
#   Using cached python_iso639-2025.2.18-py3-none-any.whl.metadata (14 kB)
# Collecting langdetect (from unstructured)
#   Using cached langdetect-1.0.9-py3-none-any.whl
# Collecting numpy (from unstructured)
#   Using cached numpy-2.3.2-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting rapidfuzz (from unstructured)
#   Using cached rapidfuzz-3.13.0-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Collecting backoff (from unstructured)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: typing-extensions in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from unstructured) (4.14.1)
# Collecting unstructured-client (from unstructured)
#   Using cached unstructured_client-0.42.0-py3-none-any.whl.metadata (23 kB)
# Collecting wrapt (from unstructured)
#   Using cached wrapt-1.17.2-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Collecting tqdm (from unstructured)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: psutil in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from unstructured) (7.0.0)
# Collecting python-oxmsg (from unstructured)
#   Using cached python_oxmsg-0.0.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting html5lib (from unstructured)
#   Using cached html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4->unstructured)
#   Using cached soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->unstructured)
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json->unstructured)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging>=17.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (25.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: six>=1.9 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from html5lib->unstructured) (1.17.0)
# Collecting webencodings (from html5lib->unstructured)
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting click (from nltk->unstructured)
#   Using cached click-8.2.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting joblib (from nltk->unstructured)
#   Using cached joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting regex>=2021.8.3 (from nltk->unstructured)
#   Using cached regex-2025.7.34-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: colorama in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from click->nltk->unstructured) (0.4.6)
# Collecting olefile (from python-oxmsg->unstructured)
#   Using cached olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from requests->unstructured) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from requests->unstructured) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from requests->unstructured) (2025.7.14)
# Collecting aiofiles>=24.1.0 (from unstructured-client->unstructured)
#   Using cached aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting cryptography>=3.1 (from unstructured-client->unstructured)
#   Using cached cryptography-45.0.5-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: httpcore>=1.0.9 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from unstructured-client->unstructured) (1.0.9)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from unstructured-client->unstructured) (0.28.1)
# Requirement already satisfied: pydantic>=2.11.2 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from unstructured-client->unstructured) (2.11.7)
# Collecting pypdf>=4.0 (from unstructured-client->unstructured)
#   Using cached pypdf-5.9.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from unstructured-client->unstructured) (1.0.0)
# Collecting cffi>=1.14 (from cryptography>=3.1->unstructured-client->unstructured)
#   Using cached cffi-1.17.1-cp312-cp312-win_amd64.whl.metadata (1.6 kB)
# Collecting pycparser (from cffi>=1.14->cryptography>=3.1->unstructured-client->unstructured)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: h11>=0.16 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from httpcore>=1.0.9->unstructured-client->unstructured) (0.16.0)
# Requirement already satisfied: anyio in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.4.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured) (1.3.1)
# Downloading unstructured-0.18.11-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------- ---------------------------- 0.5/1.8 MB 15.3 kB/s eta 0:01:22
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
#    ----------------- ---------------------- 0.8/1.8 MB 20.0 kB/s eta 0:00:50
# WARNING: Connection timed out while downloading.
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\dell\\AppData\\Local\\Temp\\pip-unpack-1f_ty_41\\unstructured-0.18.11-py3-none-any.whl'
# Consider using the `--user` option or check the permissions.
# Collecting openai
#   Downloading openai-1.98.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from openai) (4.9.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Using cached jiter-0.10.0-cp312-cp312-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from openai) (2.11.7)
# Requirement already satisfied: sniffio in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from openai) (1.3.1)
# Collecting tqdm>4 (from openai)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from openai) (4.14.1)
# Requirement already satisfied: idna>=2.8 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)
# Requirement already satisfied: colorama in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading openai-1.98.0-py3-none-any.whl (767 kB)
#    ---------------------------------------- 0.0/767.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/767.7 kB ? eta -:--:--
#    ------------- -------------------------- 262.1/767.7 kB ? eta -:--:--
#    --------------------------- ------------ 524.3/767.7 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 767.7/767.7 kB 1.2 MB/s eta 0:00:00
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached jiter-0.10.0-cp312-cp312-win_amd64.whl (206 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, jiter, distro, openai
#
#    ---------------------------------------- 0/4 [tqdm]
#    -------------------- ------------------- 2/4 [distro]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ------------------------------ --------- 3/4 [openai]
#    ---------------------------------------- 4/4 [openai]
#
# Successfully installed distro-1.9.0 jiter-0.10.0 openai-1.98.0 tqdm-4.67.1
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000018DBE8EB920>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/openai/
# Collecting Cython
#   Downloading cython-3.1.2-cp312-cp312-win_amd64.whl.metadata (6.0 kB)
# Downloading cython-3.1.2-cp312-cp312-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.7 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.7 MB 882.6 kB/s eta 0:00:03
#    ------- -------------------------------- 0.5/2.7 MB 882.6 kB/s eta 0:00:03
#    ----------- ---------------------------- 0.8/2.7 MB 958.5 kB/s eta 0:00:02
#    --------------- ------------------------ 1.0/2.7 MB 1.0 MB/s eta 0:00:02
#    ------------------- -------------------- 1.3/2.7 MB 958.5 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.6/2.7 MB 975.2 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.6/2.7 MB 975.2 kB/s eta 0:00:02
#    --------------------------- ------------ 1.8/2.7 MB 923.6 kB/s eta 0:00:01
#    ------------------------------- -------- 2.1/2.7 MB 954.7 kB/s eta 0:00:01
#    ----------------------------------- ---- 2.4/2.7 MB 980.0 kB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 1.0 MB/s eta 0:00:00
# Installing collected packages: Cython
# Successfully installed Cython-3.1.2
# Collecting tiktoken
#   Using cached tiktoken-0.9.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Collecting regex>=2022.1.18 (from tiktoken)
#   Using cached regex-2025.7.34-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: requests>=2.26.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from tiktoken) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from requests>=2.26.0->tiktoken) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from requests>=2.26.0->tiktoken) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from requests>=2.26.0->tiktoken) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from requests>=2.26.0->tiktoken) (2025.7.14)
# Using cached tiktoken-0.9.0-cp312-cp312-win_amd64.whl (894 kB)
# Downloading regex-2025.7.34-cp312-cp312-win_amd64.whl (275 kB)
# Installing collected packages: regex, tiktoken
#
#    ---------------------------------------- 0/2 [regex]
#    ---------------------------------------- 2/2 [tiktoken]
#
# Successfully installed regex-2025.7.34 tiktoken-0.9.0

# %%
# !pip install --upgrade langchain-astradb
# Out:
# Collecting langchain-astradb
#   Downloading langchain_astradb-0.6.0-py3-none-any.whl.metadata (10 kB)
# Collecting astrapy<3.0.0,>=2.0.1 (from langchain-astradb)
#   Downloading astrapy-2.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting langchain-community>=0.3.1 (from langchain-astradb)
#   Using cached langchain_community-0.3.27-py3-none-any.whl.metadata (2.9 kB)
# Collecting numpy<2.0.0,>=1.26.0 (from langchain-astradb)
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Collecting deprecation<2.2.0,>=2.1.0 (from astrapy<3.0.0,>=2.0.1->langchain-astradb)
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: httpx<1,>=0.25.2 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb) (0.28.1)
# Collecting pymongo>=3 (from astrapy<3.0.0,>=2.0.1->langchain-astradb)
#   Using cached pymongo-4.13.2-cp312-cp312-win_amd64.whl.metadata (22 kB)
# Collecting toml<0.11.0,>=0.10.2 (from astrapy<3.0.0,>=2.0.1->langchain-astradb)
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions>=4.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from astrapy<3.0.0,>=2.0.1->langchain-astradb) (4.14.1)
# Collecting uuid6>=2024.1.12 (from astrapy<3.0.0,>=2.0.1->langchain-astradb)
#   Downloading uuid6-2025.0.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from deprecation<2.2.0,>=2.1.0->astrapy<3.0.0,>=2.0.1->langchain-astradb) (25.0)
# Requirement already satisfied: anyio in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from httpx<1,>=0.25.2->httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb) (4.9.0)
# Requirement already satisfied: certifi in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from httpx<1,>=0.25.2->httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from httpx<1,>=0.25.2->httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb) (1.0.9)
# Requirement already satisfied: idna in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from httpx<1,>=0.25.2->httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.2->httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb) (0.16.0)
# Collecting h2<5,>=3 (from httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb)
#   Using cached h2-4.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb)
#   Using cached hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb)
#   Using cached hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain-community>=0.3.1->langchain-astradb) (0.3.72)
# Requirement already satisfied: langchain<1.0.0,>=0.3.26 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain-community>=0.3.1->langchain-astradb) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain-community>=0.3.1->langchain-astradb) (2.0.42)
# Requirement already satisfied: requests<3,>=2 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain-community>=0.3.1->langchain-astradb) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain-community>=0.3.1->langchain-astradb) (6.0.2)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community>=0.3.1->langchain-astradb)
#   Downloading aiohttp-3.12.15-cp312-cp312-win_amd64.whl.metadata (7.9 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain-community>=0.3.1->langchain-astradb) (9.1.2)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community>=0.3.1->langchain-astradb)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community>=0.3.1->langchain-astradb)
#   Using cached pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langsmith>=0.1.125 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain-community>=0.3.1->langchain-astradb) (0.4.10)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community>=0.3.1->langchain-astradb)
#   Using cached httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.1->langchain-astradb)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.1->langchain-astradb)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.1->langchain-astradb)
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.1->langchain-astradb)
#   Using cached frozenlist-1.7.0-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.1->langchain-astradb)
#   Using cached multidict-6.6.3-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.1->langchain-astradb)
#   Using cached propcache-0.3.2-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.1->langchain-astradb)
#   Using cached yarl-1.20.1-cp312-cp312-win_amd64.whl.metadata (76 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community>=0.3.1->langchain-astradb)
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community>=0.3.1->langchain-astradb)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain<1.0.0,>=0.3.26->langchain-community>=0.3.1->langchain-astradb) (0.3.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain<1.0.0,>=0.3.26->langchain-community>=0.3.1->langchain-astradb) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community>=0.3.1->langchain-astradb) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain-community>=0.3.1->langchain-astradb) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community>=0.3.1->langchain-astradb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community>=0.3.1->langchain-astradb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community>=0.3.1->langchain-astradb) (0.4.1)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community>=0.3.1->langchain-astradb)
#   Using cached python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain-community>=0.3.1->langchain-astradb) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain-community>=0.3.1->langchain-astradb) (2.5.0)
# Requirement already satisfied: greenlet>=1 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community>=0.3.1->langchain-astradb) (3.2.3)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community>=0.3.1->langchain-astradb)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langsmith>=0.1.125->langchain-community>=0.3.1->langchain-astradb) (3.11.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langsmith>=0.1.125->langchain-community>=0.3.1->langchain-astradb) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langsmith>=0.1.125->langchain-community>=0.3.1->langchain-astradb) (0.23.0)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo>=3->astrapy<3.0.0,>=2.0.1->langchain-astradb)
#   Using cached dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: sniffio>=1.1 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from anyio->httpx<1,>=0.25.2->httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb) (1.3.1)
# Downloading langchain_astradb-0.6.0-py3-none-any.whl (69 kB)
# Downloading astrapy-2.0.1-py3-none-any.whl (300 kB)
# Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Using cached h2-4.2.0-py3-none-any.whl (60 kB)
# Using cached hpack-4.1.0-py3-none-any.whl (34 kB)
# Using cached hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
# Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Using cached langchain_community-0.3.27-py3-none-any.whl (2.5 MB)
# Downloading aiohttp-3.12.15-cp312-cp312-win_amd64.whl (450 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Using cached multidict-6.6.3-cp312-cp312-win_amd64.whl (45 kB)
# Using cached pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached yarl-1.20.1-cp312-cp312-win_amd64.whl (86 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Using cached frozenlist-1.7.0-cp312-cp312-win_amd64.whl (43 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Using cached propcache-0.3.2-cp312-cp312-win_amd64.whl (41 kB)
# Using cached pymongo-4.13.2-cp312-cp312-win_amd64.whl (903 kB)
# Using cached dnspython-2.7.0-py3-none-any.whl (313 kB)
# Using cached python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Downloading uuid6-2025.0.1-py3-none-any.whl (7.0 kB)
# Installing collected packages: uuid6, toml, python-dotenv, propcache, numpy, mypy-extensions, multidict, marshmallow, hyperframe, httpx-sse, hpack, frozenlist, dnspython, deprecation, attrs, aiohappyeyeballs, yarl, typing-inspect, pymongo, h2, aiosignal, pydantic-settings, dataclasses-json, aiohttp, astrapy, langchain-community, langchain-astradb
#
#    -- -------------------------------------  2/27 [python-dotenv]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    ----- ----------------------------------  4/27 [numpy]
#    -------- -------------------------------  6/27 [multidict]
#    -------- -------------------------------  6/27 [multidict]
#    ---------- -----------------------------  7/27 [marshmallow]
#    ---------- -----------------------------  7/27 [marshmallow]
#    ----------- ----------------------------  8/27 [hyperframe]
#    -------------- ------------------------- 10/27 [hpack]
#    -------------- ------------------------- 10/27 [hpack]
#    ----------------- ---------------------- 12/27 [dnspython]
#    ----------------- ---------------------- 12/27 [dnspython]
#    ----------------- ---------------------- 12/27 [dnspython]
#    ----------------- ---------------------- 12/27 [dnspython]
#    ----------------- ---------------------- 12/27 [dnspython]
#    ----------------- ---------------------- 12/27 [dnspython]
#    ----------------- ---------------------- 12/27 [dnspython]
#    ----------------- ---------------------- 12/27 [dnspython]
#    ------------------- -------------------- 13/27 [deprecation]
#    -------------------- ------------------- 14/27 [attrs]
#    ----------------------- ---------------- 16/27 [yarl]
#    -------------------------- ------------- 18/27 [pymongo]
#    -------------------------- ------------- 18/27 [pymongo]
#    -------------------------- ------------- 18/27 [pymongo]
#    -------------------------- ------------- 18/27 [pymongo]
#    -------------------------- ------------- 18/27 [pymongo]
#    -------------------------- ------------- 18/27 [pymongo]
#    -------------------------- ------------- 18/27 [pymongo]
#    -------------------------- ------------- 18/27 [pymongo]
#    -------------------------- ------------- 18/27 [pymongo]
#    -------------------------- ------------- 18/27 [pymongo]
#    ---------------------------- ----------- 19/27 [h2]
#    ------------------------------- -------- 21/27 [pydantic-settings]
#    ---------------------------------- ----- 23/27 [aiohttp]
#    ---------------------------------- ----- 23/27 [aiohttp]
#    ---------------------------------- ----- 23/27 [aiohttp]
#    ---------------------------------- ----- 23/27 [aiohttp]
#    ----------------------------------- ---- 24/27 [astrapy]
#    ----------------------------------- ---- 24/27 [astrapy]
#    ----------------------------------- ---- 24/27 [astrapy]
#    ----------------------------------- ---- 24/27 [astrapy]
#    ----------------------------------- ---- 24/27 [astrapy]
#    ----------------------------------- ---- 24/27 [astrapy]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    ------------------------------------- -- 25/27 [langchain-community]
#    -------------------------------------- - 26/27 [langchain-astradb]
#    -------------------------------------- - 26/27 [langchain-astradb]
#    ---------------------------------------- 27/27 [langchain-astradb]
#
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.12.15 aiosignal-1.4.0 astrapy-2.0.1 attrs-25.3.0 dataclasses-json-0.6.7 deprecation-2.1.0 dnspython-2.7.0 frozenlist-1.7.0 h2-4.2.0 hpack-4.1.0 httpx-sse-0.4.1 hyperframe-6.1.0 langchain-astradb-0.6.0 langchain-community-0.3.27 marshmallow-3.26.1 multidict-6.6.3 mypy-extensions-1.1.0 numpy-1.26.4 propcache-0.3.2 pydantic-settings-2.10.1 pymongo-4.13.2 python-dotenv-1.1.1 toml-0.10.2 typing-inspect-0.9.0 uuid6-2025.0.1 yarl-1.20.1

# %%
# !pip install langchain langchain-openai datasets pypdf
# Out:
# Requirement already satisfied: langchain in c:\users\dell\miniconda3\envs\rag\lib\site-packages (0.3.27)
# Collecting langchain-openai
#   Downloading langchain_openai-0.3.28-py3-none-any.whl.metadata (2.3 kB)
# Collecting datasets
#   Using cached datasets-4.0.0-py3-none-any.whl.metadata (19 kB)
# Collecting pypdf
#   Using cached pypdf-5.9.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain) (0.3.72)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain) (0.3.9)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain) (0.4.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain) (2.0.42)
# Requirement already satisfied: requests<3,>=2 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain) (2025.7.14)
# Requirement already satisfied: greenlet>=1 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.3)
# Requirement already satisfied: openai<2.0.0,>=1.86.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain-openai) (1.98.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langchain-openai) (0.9.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (4.67.1)
# Requirement already satisfied: httpcore==1.* in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.86.0->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.86.0->langchain-openai) (0.16.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2025.7.34)
# Collecting filelock (from datasets)
#   Using cached filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from datasets) (1.26.4)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Using cached pyarrow-21.0.0-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting pandas (from datasets)
#   Using cached pandas-2.3.1-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting xxhash (from datasets)
#   Using cached xxhash-3.5.0-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Using cached multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Using cached fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting huggingface-hub>=0.24.0 (from datasets)
#   Downloading huggingface_hub-0.34.3-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.12.15)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langsmith>=0.1.17->langchain) (3.11.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: colorama in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.86.0->langchain-openai) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->datasets)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->datasets)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\dell\miniconda3\envs\rag\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading langchain_openai-0.3.28-py3-none-any.whl (70 kB)
# Using cached datasets-4.0.0-py3-none-any.whl (494 kB)
# Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Using cached fsspec-2025.3.0-py3-none-any.whl (193 kB)
# Using cached multiprocess-0.70.16-py312-none-any.whl (146 kB)
# Downloading pypdf-5.9.0-py3-none-any.whl (313 kB)
# Downloading huggingface_hub-0.34.3-py3-none-any.whl (558 kB)
#    ---------------------------------------- 0.0/558.8 kB ? eta -:--:--
#    ---------------------------------------- 0.0/558.8 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/558.8 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/558.8 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/558.8 kB ? eta -:--:--
#    ----------------------------------- -- 524.3/558.8 kB 466.4 kB/s eta 0:00:01
#    -------------------------------------- 558.8/558.8 kB 412.7 kB/s eta 0:00:00
# Using cached pyarrow-21.0.0-cp312-cp312-win_amd64.whl (26.2 MB)
# Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# Using cached pandas-2.3.1-cp312-cp312-win_amd64.whl (11.0 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached xxhash-3.5.0-cp312-cp312-win_amd64.whl (30 kB)
# Installing collected packages: pytz, xxhash, tzdata, pypdf, pyarrow, fsspec, filelock, dill, pandas, multiprocess, huggingface-hub, datasets, langchain-openai
#
#    ----------------------------------------  0/13 [pytz]
#    ----------------------------------------  0/13 [pytz]
#    ----------------------------------------  0/13 [pytz]
#    ----------------------------------------  0/13 [pytz]
#    ----------------------------------------  0/13 [pytz]
#    ----------------------------------------  0/13 [pytz]
#    ----------------------------------------  0/13 [pytz]
#    ----------------------------------------  0/13 [pytz]
#    ----------------------------------------  0/13 [pytz]
#    ----------------------------------------  0/13 [pytz]
#    ----------------------------------------  0/13 [pytz]
#    ----------------------------------------  0/13 [pytz]
#    ----------------------------------------  0/13 [pytz]
#    ------ ---------------------------------  2/13 [tzdata]
#    ------ ---------------------------------  2/13 [tzdata]
#    ------ ---------------------------------  2/13 [tzdata]
#    ------ ---------------------------------  2/13 [tzdata]
#    ------ ---------------------------------  2/13 [tzdata]
#    ------ ---------------------------------  2/13 [tzdata]
#    ------ ---------------------------------  2/13 [tzdata]
#    ------ ---------------------------------  2/13 [tzdata]
#    ------ ---------------------------------  2/13 [tzdata]
#    ------ ---------------------------------  2/13 [tzdata]
#    ------ ---------------------------------  2/13 [tzdata]
#    ------ ---------------------------------  2/13 [tzdata]
#    --------- ------------------------------  3/13 [pypdf]
#    --------- ------------------------------  3/13 [pypdf]
#    --------- ------------------------------  3/13 [pypdf]
#    --------- ------------------------------  3/13 [pypdf]
#    --------- ------------------------------  3/13 [pypdf]
#    --------- ------------------------------  3/13 [pypdf]
#    --------- ------------------------------  3/13 [pypdf]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    --------------- ------------------------  5/13 [fsspec]
#    --------------- ------------------------  5/13 [fsspec]
#    --------------- ------------------------  5/13 [fsspec]
#    --------------- ------------------------  5/13 [fsspec]
#    --------------- ------------------------  5/13 [fsspec]
#    ------------------ ---------------------  6/13 [filelock]
#    --------------------- ------------------  7/13 [dill]
#    --------------------- ------------------  7/13 [dill]
#    --------------------- ------------------  7/13 [dill]
#    --------------------- ------------------  7/13 [dill]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    ------------------------ ---------------  8/13 [pandas]
#    --------------------------- ------------  9/13 [multiprocess]
#    --------------------------- ------------  9/13 [multiprocess]
#    --------------------------- ------------  9/13 [multiprocess]
#    --------------------------- ------------  9/13 [multiprocess]
#    --------------------------- ------------  9/13 [multiprocess]
#    ------------------------------ --------- 10/13 [huggingface-hub]
#    ------------------------------ --------- 10/13 [huggingface-hub]
#    ------------------------------ --------- 10/13 [huggingface-hub]
#    ------------------------------ --------- 10/13 [huggingface-hub]
#    ------------------------------ --------- 10/13 [huggingface-hub]
#    ------------------------------ --------- 10/13 [huggingface-hub]
#    ------------------------------ --------- 10/13 [huggingface-hub]
#    ------------------------------ --------- 10/13 [huggingface-hub]
#    ------------------------------ --------- 10/13 [huggingface-hub]
#    ------------------------------ --------- 10/13 [huggingface-hub]
#    ------------------------------ --------- 10/13 [huggingface-hub]
#    ------------------------------ --------- 10/13 [huggingface-hub]
#    ------------------------------ --------- 10/13 [huggingface-hub]
#    ------------------------------ --------- 10/13 [huggingface-hub]
#    ------------------------------ --------- 10/13 [huggingface-hub]
#    --------------------------------- ------ 11/13 [datasets]
#    --------------------------------- ------ 11/13 [datasets]
#    --------------------------------- ------ 11/13 [datasets]
#    --------------------------------- ------ 11/13 [datasets]
#    --------------------------------- ------ 11/13 [datasets]
#    --------------------------------- ------ 11/13 [datasets]
#    --------------------------------- ------ 11/13 [datasets]
#    --------------------------------- ------ 11/13 [datasets]
#    --------------------------------- ------ 11/13 [datasets]
#    --------------------------------- ------ 11/13 [datasets]
#    --------------------------------- ------ 11/13 [datasets]
#    ------------------------------------ --- 12/13 [langchain-openai]
#    ---------------------------------------- 13/13 [langchain-openai]
#
# Successfully installed datasets-4.0.0 dill-0.3.8 filelock-3.18.0 fsspec-2025.3.0 huggingface-hub-0.34.3 langchain-openai-0.3.28 multiprocess-0.70.16 pandas-2.3.1 pyarrow-21.0.0 pypdf-5.9.0 pytz-2025.2 tzdata-2025.2 xxhash-3.5.0

# %%
# !pip install pdf2image

# %%
# !pip install pdfminer.six

# %%
# !pip install unstructured[pdf]

# %%
import os
from getpass import getpass

from datasets import (
    load_dataset,
)
from langchain_community.document_loaders import PyPDFLoader
from langchain_core.documents import Document
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.document_loaders import UnstructuredPDFLoader
from langchain.indexes import VectorstoreIndexCreator

# %%
import os
from google.colab import userdata
OPENAI_API_KEY=userdata.get('OPENAI_API_KEY')
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

embedding = OpenAIEmbeddings()

# %%
embedding = OpenAIEmbeddings()
